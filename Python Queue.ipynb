# %% [markdown]
# # Queue Data Structure
# A queue is a useful data structure in programming. It is similar to the ticket queue outside a cinema hall, where the first person entering the queue is the first person who gets the ticket.
#
# Queue follows the First In First Out (FIFO) rule - the item that goes in first is the item that comes out first.
# ![queue.webp](attachment:queue.webp)
# In the above image, since 1 was kept in the queue before 2, it is the first to be removed from the queue as well. It follows the FIFO rule.
#
# In programming terms, putting items in the queue is called enqueue, and removing items from the queue is called dequeue.

# %% [markdown]
# # Basic Operations of Queue
# A queue is an object (an abstract data structure - ADT) that allows the following operations:
#
# <ul><li><strong>Enqueue</strong>: Add an element to the end of the queue</li>
# 	<li><strong>Dequeue</strong>: Remove an element from the front of the queue</li>
# 	<li><strong>IsEmpty</strong>: Check if the queue is empty</li>
# 	<li><strong>IsFull</strong>: Check if the queue is full</li>
# 	<li><strong>Peek</strong>: Get the value of the front of the queue without removing it</li>
# </ul>

# %% [markdown]
# # Working of Queue
# Queue operations work as follows:
#
# <ul><li><strong>Enqueue</strong>: Add an element to the end of the queue</li>
# 	<li><strong>Dequeue</strong>: Remove an element from the front of the queue</li>
# 	<li><strong>IsEmpty</strong>: Check if the queue is empty</li>
# 	<li><strong>IsFull</strong>: Check if the queue is full</li>
# 	<li><strong>Peek</strong>: Get the value of the front of the queue without removing it</li>
# </ul>

# %% [markdown]
# # Enqueue Operation
# check if the queue is full
#
# 1.for the first element, set the value of FRONT to 0.
#
# 2.increase the REAR index by 1.
#
# 3.add the new element in the position pointed to by REAR
#
# # Dequeue Operation
# check if the queue is empty
#
# 1.return the value pointed by FRONT
#
# 2.increase the FRONT index by
#
# 3.for the last element, reset the values of FRONT and REAR to -3.
# ![Queue-program-enqueue-dequeue.webp](attachment:Queue-program-enqueue-dequeue.webp)

# %% [markdown]
# # Enqueue

# %%
class Queue:  
  
  def __init__(self):  
      self.queue = list()  
  
  def add_element(self,val):  
# Insert method to add element  
      if val not in self.queue:  
          self.queue.insert(0,val)  
          return True  
      return False  
  
  def size(self):  
      return len(self.queue)  
  
TheQueue = Queue()  
TheQueue.add_element("Apple")  
TheQueue.add_element("Mango")  
TheQueue.add_element("Guava")  
TheQueue.add_element("Papaya")  
  
print("The length of Queue: ",TheQueue.size())
# Out:
# The length of Queue:  4

# %% [markdown]
# # Dequeue

# %%
class Queue:  
  
  def __init__(self):  
      self.queue = list()  
  
  def add_element(self,val):  
# Insert method to add element  
      if val not in self.queue:  
          self.queue.insert(0,val)  
          return True  
      return False  
# Pop method to remove element  
  def remove_element(self):  
      if len(self.queue)>0:  
          return self.queue.pop()  
      return ("Queue is Empty")  
  
que = Queue()  
que.add_element("January")  
que.add_element("February")  
que.add_element("March")  
que.add_element("April")  
  
print(que)  
print(que.remove_element())  
print(que.remove_element())
# Out:
# <__main__.Queue object at 0x0000020C50999460>
# January
# February

# %% [markdown]
# # Limitations of Queue
# As you can see in the image below, after a bit of enqueuing and dequeuing, the size of the queue has been reduced.
#
# ![why-circular-queue_0.webp](attachment:why-circular-queue_0.webp)
#
# And we can only add indexes 0 and 1 only when the queue is reset (when all the elements have been dequeued).
#
# After REAR reaches the last index, if we can store extra elements in the empty spaces (0 and 1), we can make use of the empty spaces. This is implemented by a modified queue called the circular queue.

# %% [markdown]
# # Complexity Analysis
# The complexity of enqueue and dequeue operations in a queue using an array is O(1). If you use pop(N) in python code, then the complexity might be O(n) depending on the position of the item to be popped.

# %% [markdown]
# # Applications of Queue
# CPU scheduling, Disk Scheduling
#
# When data is transferred asynchronously between two processes.The queue is used for synchronization. For example: IO Buffers, pipes, file IO, etc
#
# Handling of interrupts in real-time systems.
#
# Call Center phone systems use Queues to hold people calling them in order.
